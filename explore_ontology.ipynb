# %%
import pandas as pd
import text2term

# %% [markdown]
# #### Read in Microbes in Periodontitis and Health Data:

# %%
micro_list = pd.read_excel(
    'Feres_PeriodontalMicrobiome/data/Cleaned Micro List RY_final.xlsx',
    sheet_name='New DATABASE', 
    header=[0, 1])

# %%
print(micro_list.columns)
# Out:
# MultiIndex([(                        'Unnamed: 0_level_0',    'Number'),
#             (                        'Unnamed: 1_level_0', 'Reference'),
#             (       'Species elevated in health (p<0.05)',    'Domain'),
#             (       'Species elevated in health (p<0.05)',   'Kingdom'),
#             (       'Species elevated in health (p<0.05)',    'Phylum'),
#             (       'Species elevated in health (p<0.05)',     'Class'),
#             (       'Species elevated in health (p<0.05)',     'Order'),
#             (       'Species elevated in health (p<0.05)',    'Family'),
#             (       'Species elevated in health (p<0.05)',     'Genus'),
#             (       'Species elevated in health (p<0.05)',   'Species'),
#             (       'Species elevated in health (p<0.05)', 'Species.1'),
#             ('Species elevated in periodontitis (p<0.05)',    'Domain'),
#             ('Species elevated in periodontitis (p<0.05)',   'Kingdom'),
#             ('Species elevated in periodontitis (p<0.05)',    'Phylum'),
#             ('Species elevated in periodontitis (p<0.05)',     'Class'),
#             ('Species elevated in periodontitis (p<0.05)',     'Order'),
#             ('Species elevated in periodontitis (p<0.05)',    'Family'),
#             ('Species elevated in periodontitis (p<0.05)',     'Genus'),
#             ('Species elevated in periodontitis (p<0.05)',   'Species')],
#            )

# %%
micro_perio = micro_list['Species elevated in periodontitis (p<0.05)']

# %%
micro_perio.head()
# Out:
#      Domain   Kingdom          Phylum                  Class  \
# 0  Bacteria  Bacteria   Bacteroidetes            Bacteroidia
# 1  Bacteria  Bacteria   Bacteroidetes            Bacteroidia
# 2  Bacteria  Bacteria  Proteobacteria  Epsilonproteobacteria
# 3  Bacteria  Bacteria   Bacteroidetes         Flavobacteriia
# 4  Bacteria  Bacteria  Proteobacteria  Epsilonproteobacteria
#
#                Order              Family           Genus      Species
# 0      Bacteroidales      Prevotellaceae  Alloprevotella     tannerae
# 1      Bacteroidales      Bacteroidaceae   Bacteroidales          sp.
# 2  Campylobacterales  Campylobacteraceae   Campylobacter     gracilis
# 3   Flavobacteriales   Flavobacteriaceae  Capnocytophaga  leadbetteri
# 4  Campylobacterales  Campylobacteraceae   Campylobacter       rectus

# %%
micro_domain = micro_perio['Domain'].dropna().unique().tolist()

# %%
micro_domain
# Out:
# ['Bacteria']

# %% [markdown]
# #### Cache the NCBI Taxon:

# %%
ncbi_taxon = text2term.cache_ontology(ontology_url="http://purl.obolibrary.org/obo/ncbitaxon.owl", 
                                 ontology_acronym="NCBITaxon")
# Out:
# 2025-09-03 11:38:58 INFO [text2term.term_collector]: Loading ontology http://purl.obolibrary.org/obo/ncbitaxon.owl...
# 2025-09-03 11:43:12 INFO [text2term.term_collector]: ...done (ontology loading time: 163.14s)
# 2025-09-03 11:43:12 INFO [text2term.term_collector]: Collecting ontology term details...
# 2025-09-03 11:45:41 INFO [text2term.term_collector]: ...done: collected 2650614 ontology terms (collection time: 149.25s)
# 2025-09-03 11:46:42 INFO [text2term.t2t]: Filtered ontology terms to those of type: OntologyTermType.ANY
# 2025-09-03 11:46:42 INFO [text2term.t2t]: Caching ontology http://purl.obolibrary.org/obo/ncbitaxon.owl to: .cache/NCBITaxon

# %% [markdown]
# #### Use it to map domain terms:

# %%
ncbi_taxon.map_terms(source_terms=micro_domain)
# Out:
# 2025-09-03 11:52:21 INFO [text2term.t2t]: Loading cached ontology from: .cache/NCBITaxon/NCBITaxon-term-details.pickle
# 2025-09-03 11:52:31 INFO [text2term.t2t]: Filtered ontology terms to those of type: OntologyTermType.CLASS
# 2025-09-03 11:52:31 INFO [text2term.t2t]: Mapping 1 source terms to NCBITaxon
# 2025-09-03 11:53:09 INFO [text2term.t2t]: ...done (mapping time: 37.79s seconds)
#                         Source Term ID Source Term  \
# 0  https://text2term.utils/RGjSYbiiqPA    Bacteria
# 1  https://text2term.utils/RGjSYbiiqPA    Bacteria
# 2  https://text2term.utils/RGjSYbiiqPA    Bacteria
#
#                    Mapped Term Label  Mapped Term CURIE  \
# 0                           Bacteria        NCBITAXON:2
# 1  Candidatus Peribacteria bacterium  NCBITAXON:2053688
# 2  Candidatus Poribacteria bacterium  NCBITAXON:2026781
#
#                                     Mapped Term IRI  Mapping Score  Tags
# 0        http://purl.obolibrary.org/obo/NCBITaxon_2          0.994  None
# 1  http://purl.obolibrary.org/obo/NCBITaxon_2053688          0.770  None
# 2  http://purl.obolibrary.org/obo/NCBITaxon_2026781          0.741  None

# %% [markdown]
# #### Use it to map genus terms:

# %%
micro_genus = micro_perio['Genus'].dropna().unique()

# %%
micro_genus
# Out:
# array(['Alloprevotella', 'Bacteroidales', 'Campylobacter',
#        'Capnocytophaga', 'Desulfobulbus', 'Dialister', 'Enterococcus',
#        'Filifactor', 'Fretibacterium', 'Fusobacterium', 'Lachnospiracee',
#        'Leptotrichia', 'Mycoplasma', 'Parvimonas', 'Peptoniphilaceae',
#        'Porphyromonas', 'Prevotella', 'Selenomonas', 'Tannerella',
#        'Tessnema', 'Treponema', 'Aggregatibacter', 'Lachnospiraceae G8',
#        'Mogibacterium', 'Peptostreptococcaceae XI G4',
#        'Peptostreptococcaceae XI G5', 'Peptostreptococcaceae XI G6',
#        'Bacteroidetes G-3', 'Lachnospiraceae G-8',
#        'Peptostreptococcaceae XIG-1', 'Peptostreptococcaceae XIG-4',
#        'Peptostreptococcaceae XIG-5', 'Peptostreptococcus',
#        'Saccharibacteria TM7 G-1', 'Saccharibacteria TM7 G-5',
#        'Veillonellaceae G-1', 'Bacteroidaceae [G-1]', 'Bacteroides',
#        'Actinomyces', 'Bacteroidetes [G-3]', 'Bacteroidetes [G-5]',
#        'Eubacterium', 'Lachnospiraceae [G-8]', 'Peptococcus',
#        'Peptostreptococcaceae [XI] [G-4]', 'Sneathia', 'Solobacterium',
#        'Veillonellaceae [G-1]', 'Streptococcus', 'Arthrobacter',
#        'Bacillus', 'Bifidobacterium', 'Catenulispora', 'Clostridium',
#        'Corynebacterium', 'Gardnerella', 'Gordonia', 'Herbaspirillum',
#        'Klebsiella', 'Mannheimia', 'Mobiluncus', 'Mycobacterium',
#        'Nocardiopsis', 'Rhodococcus', 'Roseobacter', 'Streptomyces',
#        'Streptosporangium', 'Variovorax', 'Verminephrobacter',
#        'Unclassified', 'Olsenella', 'Saccharibacteria (TM7) [G-5]-like',
#        'Peptoniphilaceae [G-1]', 'Cardiobacterium'], dtype=object)

# %%
ncbi_taxon.map_terms(source_terms=micro_genus)
# Out:
# 2025-09-03 12:08:12 INFO [text2term.t2t]: Loading cached ontology from: .cache/NCBITaxon/NCBITaxon-term-details.pickle
# 2025-09-03 12:08:20 INFO [text2term.t2t]: Filtered ontology terms to those of type: OntologyTermType.CLASS
# 2025-09-03 12:08:20 INFO [text2term.t2t]: Mapping 74 source terms to NCBITaxon
# 2025-09-03 12:08:59 INFO [text2term.t2t]: ...done (mapping time: 38.65s seconds)
#                           Source Term ID             Source Term  \
# 0    https://text2term.utils/RGTetkHL5V6          Alloprevotella
# 1    https://text2term.utils/RGTetkHL5V6          Alloprevotella
# 2    https://text2term.utils/RGTetkHL5V6          Alloprevotella
# 3    https://text2term.utils/RmtdD8ijUgq           Bacteroidales
# 4    https://text2term.utils/RmtdD8ijUgq           Bacteroidales
# ..                                   ...                     ...
# 217  https://text2term.utils/REFF4sUTPuB  Peptoniphilaceae [G-1]
# 218  https://text2term.utils/REFF4sUTPuB  Peptoniphilaceae [G-1]
# 219  https://text2term.utils/RJ2WgkGb5in         Cardiobacterium
# 220  https://text2term.utils/RJ2WgkGb5in         Cardiobacterium
# 221  https://text2term.utils/RJ2WgkGb5in         Cardiobacterium
#
#                  Mapped Term Label  Mapped Term CURIE  \
# 0                   Alloprevotella  NCBITAXON:1283313
# 1               Alloprevotella sp.  NCBITAXON:1872471
# 2              Alloprevotella rava   NCBITAXON:671218
# 3                    Bacteroidales   NCBITAXON:171549
# 4          Bacteroidales bacterium  NCBITAXON:2030927
# ..                             ...                ...
# 217     Peptoniphilaceae bacterium  NCBITAXON:1891242
# 218  unclassified Peptoniphilaceae  NCBITAXON:1689302
# 219                Cardiobacterium     NCBITAXON:2717
# 220            Cardiobacterium sp.  NCBITAXON:2382124
# 221          Cardiobacterium sp. A    NCBITAXON:93719
#
#                                       Mapped Term IRI  Mapping Score  Tags
# 0    http://purl.obolibrary.org/obo/NCBITaxon_1283313          0.982  None
# 1    http://purl.obolibrary.org/obo/NCBITaxon_1872471          0.973  None
# 2     http://purl.obolibrary.org/obo/NCBITaxon_671218          0.825  None
# 3     http://purl.obolibrary.org/obo/NCBITaxon_171549          0.974  None
# 4    http://purl.obolibrary.org/obo/NCBITaxon_2030927          0.874  None
# ..                                                ...            ...   ...
# 217  http://purl.obolibrary.org/obo/NCBITaxon_1891242          0.839  None
# 218  http://purl.obolibrary.org/obo/NCBITaxon_1689302          0.748  None
# 219     http://purl.obolibrary.org/obo/NCBITaxon_2717          0.992  None
# 220  http://purl.obolibrary.org/obo/NCBITaxon_2382124          0.978  None
# 221    http://purl.obolibrary.org/obo/NCBITaxon_93719          0.954  None
#
# [222 rows x 7 columns]
